# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.ion()
import pandas as pd
import pickle

# %%
d = pickle.load(open("foobar", "rb"))
d
# Out:
# {(0, 'high'): <dragonboard.runningstats.RunningStats at 0x7f33e3d0b978>,
#  (0, 'low'): <dragonboard.runningstats.RunningStats at 0x7f33e3df86d8>,
#  (1, 'high'): <dragonboard.runningstats.RunningStats at 0x7f33e3df8ac8>,
#  (1, 'low'): <dragonboard.runningstats.RunningStats at 0x7f33e3df84e0>,
#  (2, 'high'): <dragonboard.runningstats.RunningStats at 0x7f33e3dedd68>,
#  (2, 'low'): <dragonboard.runningstats.RunningStats at 0x7f33e62a0e80>,
#  (3, 'high'): <dragonboard.runningstats.RunningStats at 0x7f33e3d0b400>,
#  (3, 'low'): <dragonboard.runningstats.RunningStats at 0x7f33e3de4390>,
#  (4, 'high'): <dragonboard.runningstats.RunningStats at 0x7f33e3df88d0>,
#  (4, 'low'): <dragonboard.runningstats.RunningStats at 0x7f33e62a0d68>,
#  (5, 'high'): <dragonboard.runningstats.RunningStats at 0x7f33e3de4e48>,
#  (5, 'low'): <dragonboard.runningstats.RunningStats at 0x7f33e3f2eba8>,
#  (6, 'high'): <dragonboard.runningstats.RunningStats at 0x7f33e3de4a20>,
#  (6, 'low'): <dragonboard.runningstats.RunningStats at 0x7f33e3f2ec18>,
#  (7, 'high'): <dragonboard.runningstats.RunningStats at 0x7f33e62a0e48>,
#  (7, 'low'): <dragonboard.runningstats.RunningStats at 0x7f33e3df8cc0>}

# %%
fig, axes = plt.subplots(8, 2, sharex=True, sharey=True, figsize=(12, 24))
for channel in range(8):
    for ig, gaintype in enumerate(["high", "low"]):
        ax = axes[channel, ig]
        ax.errorbar(
            x=np.arange(len(s.mean)),
            y=s.mean,
            yerr=s.sem,
            fmt='.')
        ax.set_xlim(0, 4096)
        ax.set_title("channel:{0} {1}".format(channel, gaintype))
        ax.grid()

# %%
fig, axes = plt.subplots(8, 2, sharex=True, sharey=True, figsize=(12, 24))
for channel in range(8):
    for ig, gaintype in enumerate(["high", "low"]):
        ax = axes[channel, ig]
        ax.plot(s.n)
        ax.set_xlim(0, 4096)
        ax.set_title("channel:{0} {1}".format(channel, gaintype))
        ax.grid()
        ax.set_ylim(0, 1e4)
